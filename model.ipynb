# %%
import os
import asyncio
from openai import OpenAI
from dotenv import load_dotenv
from QwenIELTSEvaluator import QwenIELTSEvaluator
import whisper
from pathlib import Path
from utils import save_txt

# %%
# !pip install dotenv
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv, dotenv
# Successfully installed dotenv-0.9.9 python-dotenv-1.2.1

# %%
load_dotenv()
DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
testset_dir = Path("./testset")
if not testset_dir.exists():
    print("'testset' folder not found. Create it and add subfolders with MP3 files.")
    exit(1)
    
evaluator = QwenIELTSEvaluator(api_key=DASHSCOPE_API_KEY)
model = whisper.load_model("base") 

count = 1
    
for subdir in testset_dir.iterdir():
    if not subdir.is_dir():
        continue  # Skip non-folders

    if count >= 10:
        break  # Limit to 10 folders for testing
        
    print(f"\n" + "="*50)
    print(f"Processing: {subdir.name}")
    print("="*50)
    
    base_url = f"https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/{subdir.name}/{subdir.name}_"
    part_one = f"{base_url}part_1.mp3"
    part_two = f"{base_url}part_2.mp3"
    part_three = f"{base_url}part_3.mp3"
    feedback = subdir / f"{subdir.name}_feedback.mp3"
    
    if not feedback.exists():
        print(f"Feedback MP3 not found for {subdir.name}: {feedback}")
        continue
    
    # Track results and errors
    results = {}
    errors = {}
    
    # Evaluate Part 1
    print("\nEvaluating Part 1...")
    try:
        p1_result = evaluator.evaluate_audio(part_one)
        results['part1'] = p1_result
        save_txt(p1_result, str(subdir / "part1_feedback.txt"))
    except Exception as e:
        error_msg = f"Error in Part 1: {str(e)}"
        print(f"{error_msg}")
        errors['part1'] = error_msg
        results['part1'] = None
    
    # Evaluate Part 2
    print("\nEvaluating Part 2...")
    try:
        p2_result = evaluator.evaluate_audio(part_two)
        results['part2'] = p2_result
        save_txt(p2_result, str(subdir / "part2_feedback.txt"))
    except Exception as e:
        error_msg = f"Error in Part 2: {str(e)}"
        print(f"{error_msg}")
        errors['part2'] = error_msg
        results['part2'] = None
    
    # Evaluate Part 3
    print("\nEvaluating Part 3...")
    try:
        p3_result = evaluator.evaluate_audio(part_three)
        results['part3'] = p3_result
        save_txt(p3_result, str(subdir / "part3_feedback.txt"))
    except Exception as e:
        error_msg = f"Error in Part 3: {str(e)}"
        print(f"{error_msg}")
        errors['part3'] = error_msg
        results['part3'] = None
    
    # Check if we have at least one successful result
    successful_parts = [k for k, v in results.items() if v is not None]
    
    if not successful_parts:
        print("\nALL PARTS FAILED - Skipping evaluation for this folder")
        continue
    
    # Combine successful feedback
    print(f"\nSuccessfully evaluated: {', '.join(successful_parts)}")
    if errors:
        print(f"Failed parts: {', '.join(errors.keys())}")
    
    # Build combined feedback from successful parts only
    feedback_parts = []
    if results['part1']:
        feedback_parts.append(f"Part 1:\n{results['part1']}")
    if results['part2']:
        feedback_parts.append(f"Part 2:\n{results['part2']}")
    if results['part3']:
        feedback_parts.append(f"Part 3:\n{results['part3']}")
    
    generated_feedback = "\n\n---\n\n".join(feedback_parts)
    
    output_file1 = subdir / "model_feedback.txt"
    save_txt(generated_feedback, str(output_file1))
    
    model_feedback_dir = testset_dir / "model_feedback"
    output_file2 = model_feedback_dir / f"{subdir.name}.txt"
    save_txt(generated_feedback, str(output_file2))

    count += 1
# Out:
# ==================================================
# Processing: -awN8jpvDFo_7_0
# ==================================================
#
# Evaluating Part 1...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/-awN8jpvDFo_7_0/-awN8jpvDFo_7_0_part_1.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate speaks at length with good coherence and a range of vocabulary, though some hesitation and grammatical errors prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate generally speaks at length with a good pace and maintains topic relevance throughout the conversation. She uses a variety of cohesive devices such as "and also," "but still," and "because" to link ideas effectively. However, there are noticeable hesitations and fillers like "um" and "like" that interrupt the flow, particularly when she is thinking of words (e.g., "I'm like right now living in a place called..."). While she manages to stay on topic, the pauses and repetition of phrases like "I'm thinking that I could learn from like anybody, anything" suggest some effort in maintaining a smooth, natural delivery, which aligns with a Band 7 performance.
#
#    **Lexical Resource**: The candidate demonstrates a strong and varied vocabulary appropriate for the topics discussed. She uses precise terms such as "freelancer," "massive fandom," and "life-giving meaning" to express her ideas effectively. Her ability to paraphrase is evident when she describes her hometown as "a kind of a bad town" and later explains that "the part when we have to study" is boring. This flexibility and range of vocabulary, including topic-specific terms like "idol groups" and "politics," contribute to a Band 7.5 score, showing a good command of language beyond basic expressions.
#
#    **Grammatical Range and Accuracy**: The candidate uses a mix of simple and complex sentence structures, such as "I think it's a really meaningful thing for me to do as a living" and "I could learn from like anybody, anything." However, there are frequent grammatical errors, including incorrect verb forms ("I'm like right now living"), missing articles ("a place called Jungnang-gu"), and incorrect prepositions ("connected to the politics"). While she attempts more complex constructions, the errors in basic grammar and sentence structure prevent a higher score, placing her in the Band 6.5 range.
#
#    **Pronunciation**: The candidate's pronunciation is generally clear and easy to understand, with good use of intonation and rhythm that reflects natural speech patterns. Her stress and word pronunciation are accurate, such as in "freelancer" and "communication." However, there are some minor issues, like the elongated "um" sounds and occasional mispronunciations (e.g., "Jungnang-gu" may be slightly mispronounced). Despite these small issues, her overall delivery is fluent and intelligible, which supports a Band 7 score.
#
# Usage Info: CompletionUsage(completion_tokens=620, prompt_tokens=6968, total_tokens=7588, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=620), prompt_tokens_details=PromptTokensDetails(audio_tokens=6001, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\-awN8jpvDFo_7_0\part1_feedback.txt
#
# Evaluating Part 2...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/-awN8jpvDFo_7_0/-awN8jpvDFo_7_0_part_2.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate delivers a coherent and relevant response with good fluency and a range of vocabulary and grammar, though some hesitation and minor grammatical errors prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at length with a generally smooth flow, maintaining relevance to the prompt about noisy public transport. They use cohesive devices like "so," "and," and "because" effectively to link ideas, and their narrative structure is clear. However, there are noticeable pauses and self-corrections (e.g., "um" and "like" fillers), and a slight hesitation when describing the friend's phone call ("my friend was making a short call with her boyfriend and her voice got louder and louder because of the crowded people like the loud noises that the people made"). These interruptions, while not disrupting overall coherence, are characteristic of Band 7 rather than the effortless fluency of Band 8 or 9.
#
#    **Lexical Resource**: The candidate demonstrates a strong vocabulary range, using topic-specific terms like "public transportation," "crowded," "loud noises," and "anxiety." They also employ more sophisticated phrases such as "ethics in public transportation" and "made a lot of noise," showing flexibility and an attempt at paraphrase. The vocabulary is generally precise and appropriate for the context, contributing to a clear and expressive response. This level of lexical variety and control aligns with a Band 7.5.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex structures, such as "I think people should be... like need etiquettes in the public transportation" and "that time was when my nearest person made a lot of noise." However, there are noticeable grammatical inaccuracies, including the incorrect phrase "need etiquettes" (should be "etiquette") and the awkward construction "the time when my nearest person made a lot of noise" (should be "closest person"). While the candidate uses some complex sentences effectively, these errors, along with occasional tense inconsistencies, limit the score to Band 6.5.
#
#    **Pronunciation**: The candidate's pronunciation is clear and easy to understand throughout the response. They use appropriate stress and intonation, particularly in longer sentences like "I think it depends on the time that you get on the subway." There are no significant mispronunciations that hinder comprehension, and the rhythm of speech is natural. The candidate's delivery is confident and consistent, which supports a Band 7 score.
#
# Usage Info: CompletionUsage(completion_tokens=583, prompt_tokens=4568, total_tokens=5151, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=583), prompt_tokens_details=PromptTokensDetails(audio_tokens=3601, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\-awN8jpvDFo_7_0\part2_feedback.txt
#
# Evaluating Part 3...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/-awN8jpvDFo_7_0/-awN8jpvDFo_7_0_part_3.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate demonstrates good fluency and coherence with a clear range of vocabulary and grammatical structures, though some hesitation and minor grammatical inaccuracies prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at length with a generally smooth flow, using appropriate discourse markers like "because" and "so" to connect ideas. For example, she explains her reasoning for choosing parks as noise-free places by linking the outdoor setting to people's freedom to rest and children's ability to play. However, there are noticeable pauses and self-corrections, such as "uh, I think the most noise-free place that was um like that took my mind was," which slightly disrupts the natural rhythm. These hesitations are typical of Band 7, where fluency is maintained but not effortless.
#
#    **Lexical Resource**: The candidate uses a good range of vocabulary relevant to the topic, including "playground," "parks," "public transportation," and "anxiety." She also demonstrates flexibility by paraphrasing, such as saying "the place is very accessible in any places" instead of simply "easy to reach." Her use of "I wish that people could be quiet in that place" shows an attempt to express personal opinion with appropriate phrasing. This variety and precision support a Band 7.5 score.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex structures, such as "that place is very accessible in any places because that river is like in the middle of our capital city." However, there are grammatical inaccuracies, including "in any places" (should be "in all places") and "that took my mind was" (awkward phrasing). She also uses "I'm a person who studied about communication" instead of "I studied" or "I am studying," showing some control but with errors that affect clarity. These issues prevent a higher score in this criterion.
#
#    **Pronunciation**: The candidate's pronunciation is generally clear and easy to understand, with good use of intonation and rhythm. For example, her pitch rises appropriately when asking "And do you think people should be allowed to make noise in all public areas?" This shows awareness of discourse features. However, there are some minor mispronunciations, such as "Han River" (possibly intended as "Hantan River" or similar), and occasional unclear word boundaries, like "I'm a bit feel frustrated." These do not hinder understanding but prevent a Band 8.
#
# Usage Info: CompletionUsage(completion_tokens=585, prompt_tokens=7518, total_tokens=8103, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=585), prompt_tokens_details=PromptTokensDetails(audio_tokens=6551, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\-awN8jpvDFo_7_0\part3_feedback.txt
#
# Successfully evaluated: part1, part2, part3
# Saved: testset\-awN8jpvDFo_7_0\model_feedback.txt
# Saved: testset\model_feedback\-awN8jpvDFo_7_0.txt
#
# ==================================================
# Processing: 2e8FnaI8skE_5_0
# ==================================================
#
# Evaluating Part 1...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/2e8FnaI8skE_5_0/2e8FnaI8skE_5_0_part_1.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate speaks at length with generally smooth fluency, uses a range of vocabulary and grammatical structures appropriately, and maintains coherence throughout the responses, though with some hesitation and minor grammatical inaccuracies.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at length with a generally smooth flow, using discourse markers like "so" and "but" to connect ideas. For example, they say, "I really like to hang out with my friends and also meet new people so I can connect new... new experience or new people," which shows an attempt to extend the response coherently. However, there are noticeable hesitations ("um," "uh") and self-corrections ("I mean new people"), which slightly disrupt the natural rhythm. These features align with Band 7, where fluency is generally fluent but not effortless, with some repetition and hesitation.
#
#    **Lexical Resource**: The candidate demonstrates a good range of vocabulary, using phrases like "connect new experience," "meet new people," and "find some new chance," which shows flexibility and an attempt to paraphrase. They also use appropriate collocations such as "really welcome them" and "strict schedule." The vocabulary is generally precise and relevant to the topic, which is characteristic of Band 7.5, where the candidate uses less common items with some style awareness, though there is occasional awkwardness in word choice.
#
#    **Grammatical Range and Accuracy**: The candidate uses a mix of simple and complex structures, such as "I also find some new chance that I can meet new people," which shows an attempt at complex sentence construction. However, there are noticeable grammatical errors, such as "I mean new people" (repetition) and "I really welcome them so if they welcome to me" (incorrect use of "welcome to me"). These errors, while not severely impacting understanding, prevent a higher score. This aligns with Band 6.5, where the candidate uses a mix of structures but with frequent errors that affect clarity.
#
#    **Pronunciation**: The candidate's pronunciation is generally clear and easy to understand, with appropriate stress and intonation in most parts of the response. For example, in "I really like to hang out with my friends," the stress is correctly placed on "really" and "friends." However, there are some minor mispronunciations, such as "chance" being pronounced as "chance" with a slight vowel shift, and occasional unclear word boundaries. These features are typical of Band 7, where pronunciation is generally effective and does not impede understanding, though there are some lapses in rhythm and intonation.
#
# Usage Info: CompletionUsage(completion_tokens=612, prompt_tokens=4543, total_tokens=5155, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=612), prompt_tokens_details=PromptTokensDetails(audio_tokens=3576, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\2e8FnaI8skE_5_0\part1_feedback.txt
#
# Evaluating Part 2...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/2e8FnaI8skE_5_0/2e8FnaI8skE_5_0_part_2.mp3
#
# Response:
#
# 1. **Overall Band Score**: 6.5 – The candidate demonstrates a generally coherent and fluent response with a good range of vocabulary and grammatical structures, though occasional hesitation and grammatical inaccuracies prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 6.5
#    - Lexical Resource: 7.0
#    - Grammatical Range and Accuracy: 6.0
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at a generally natural pace with a clear attempt to develop a coherent response. They use basic cohesive devices like "because" and "and" to link ideas, and their topic development is relevant and sustained throughout the two-minute timeframe. However, there are noticeable hesitations and self-corrections, such as the repeated "or" in "I also think so, yeah, I want to go someday or I want to know about more," which disrupts fluency and suggests some effort in retrieving vocabulary. This aligns with Band 6.5, where fluency is generally smooth but with occasional lapses.
#
#    **Lexical Resource**: The candidate demonstrates a sufficient range of vocabulary for the topic, using words like "amazing," "fascinating," "ancient treasures," and "landscapes" to describe Egypt. They also attempt to paraphrase by saying "I want to know about more" instead of "learn more," showing some awareness of lexical variety. The vocabulary is appropriate and relevant, with a mix of general and topic-specific terms, which supports a Band 7 score. However, there is some repetition of "I want to know" and "I want to go," which slightly limits the lexical range.
#
#    **Grammatical Range and Accuracy**: The candidate uses a mix of simple and compound sentences, such as "I've seen many movies and documentaries about Egypt and I think their culture is really amazing." However, there are noticeable grammatical errors, including the incorrect use of "or" in "I also think so, yeah, I want to go someday or I want to know about more," which shows confusion between coordinating conjunctions. Additionally, the phrase "I always want to know about more Egypt" is grammatically incorrect; it should be "I always want to know more about Egypt." These errors, while not severely impacting meaning, affect grammatical accuracy and limit the score to Band 6.
#
#    **Pronunciation**: The candidate's pronunciation is clear and easy to understand throughout the response. They use appropriate stress and intonation, such as in "ancient treasures" and "I want to go someday," which enhances the natural flow of speech. There are no significant mispronunciations that hinder comprehension, and the rhythm is generally consistent. This level of clarity and intelligibility supports a Band 7 score.
#
# Usage Info: CompletionUsage(completion_tokens=596, prompt_tokens=2743, total_tokens=3339, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=596), prompt_tokens_details=PromptTokensDetails(audio_tokens=1776, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\2e8FnaI8skE_5_0\part2_feedback.txt
#
# Evaluating Part 3...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/2e8FnaI8skE_5_0/2e8FnaI8skE_5_0_part_3.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate speaks at length with generally good fluency and coherence, using a range of vocabulary and grammatical structures with sufficient accuracy to convey ideas clearly. While there are some hesitations and grammatical errors, they do not significantly impede understanding.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate generally speaks at length without significant pauses, demonstrating a good ability to maintain the topic. For example, they provide a detailed response to the question about learning foreign cultures, using phrases like "I think if you use social media well" to structure their answer. However, there are noticeable hesitations, such as "um" and "uh" fillers, and a slight repetition when saying "I can I I think," which indicates some effort in organizing thoughts. These features align with Band 7, where fluency is flexible but not effortless.
#
#    **Lexical Resource**: The candidate uses a range of vocabulary relevant to the topic, including "social media," "immerse their culture," and "improve your language skills." They also demonstrate some flexibility by using phrases like "really high" to emphasize a point. The vocabulary is generally precise and appropriate, showing awareness of idiomatic expressions, which supports a Band 7.5 score. However, there is occasional repetition of words like "language" and "culture," which slightly limits the lexical range.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex structures, such as "I think if you use social media well, then it can improve your language skills really high." However, there are noticeable grammatical errors, such as "it can improve yours language skills really high," which shows a lack of accuracy in article usage and word order. Additionally, the sentence "that I can translate every language in my head first and then I have to say" contains grammatical issues that affect clarity. These errors prevent a higher score, placing the candidate in Band 6.5.
#
#    **Pronunciation**: The candidate's pronunciation is generally clear and easy to understand, with good use of intonation and rhythm. For example, their delivery of "I think if you use social media well" is natural and fluent. However, there are some minor pronunciation issues, such as the mispronunciation of "language" as "linguage" and "social media" as "sociar media," which slightly affect intelligibility. These features are consistent with Band 7, where pronunciation is effective but not fully native-like.
#
# Usage Info: CompletionUsage(completion_tokens=581, prompt_tokens=3543, total_tokens=4124, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=581), prompt_tokens_details=PromptTokensDetails(audio_tokens=2576, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\2e8FnaI8skE_5_0\part3_feedback.txt
#
# Successfully evaluated: part1, part2, part3
# Saved: testset\2e8FnaI8skE_5_0\model_feedback.txt
# Saved: testset\model_feedback\2e8FnaI8skE_5_0.txt
#
# ==================================================
# Processing: 2RaNq8rmsGA_8_0
# ==================================================
#
# Evaluating Part 1...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/2RaNq8rmsGA_8_0/2RaNq8rmsGA_8_0_part_1.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate speaks at length with generally smooth fluency, uses a good range of vocabulary and grammatical structures, and is easily understood despite some hesitation and minor grammatical errors.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate generally speaks at length without significant pauses, demonstrating a good ability to maintain the conversation. She uses a range of cohesive devices such as "but," "so," and "whenever" to link ideas, which helps maintain coherence. However, there are occasional hesitations and self-corrections (e.g., "um, I'm trying to like my major because I used to study..."), which slightly disrupt the flow. These features are typical of a Band 7 candidate who can express ideas fluently but may not always speak with complete spontaneity.
#
#    **Lexical Resource**: The candidate demonstrates a strong vocabulary range, using topic-specific terms like "bilingual MC," "freelance interpreter," and "amusement park" with accuracy. She also paraphrases effectively, saying "I'm trying to like my major" instead of "I'm trying to adapt to my major." Her use of phrases like "step out of my comfort zone" and "broaden my horizon" shows good lexical flexibility and idiomatic awareness, which supports a Band 7.5 score.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex sentences, such as "I always get to meet various people like I always work with different clients, different audiences," which shows an effort to vary structure. However, there are noticeable grammatical errors, including subject-verb agreement ("I'm trying to like my major because I used to study culture anthropology, but I found out that it's not really my things") and tense inconsistency ("I always have to go to Seoul so that's not good 'cause when I'm drunk I have to get back to Yongin but that's nearly impossible"). These errors, while not impeding understanding, prevent a higher score.
#
#    **Pronunciation**: The candidate's pronunciation is clear and easy to understand throughout. She uses appropriate intonation and stress patterns, such as emphasizing "Everland" and "Seoul" to convey meaning. Her rhythm is natural, and she uses connected speech effectively (e.g., "I'm kind of stuck in the subway every morning"). There are no persistent mispronunciations that hinder comprehension, which aligns with Band 7 features.
#
# **Suggestions for Improvement**:
# To reach Band 8, focus on reducing grammatical errors by reviewing subject-verb agreement and tense consistency. Practice speaking more spontaneously to minimize hesitations. To improve pronunciation, work on mastering the correct pronunciation of less common words like "anthropology" and "transfer" to enhance clarity further.
#
# Usage Info: CompletionUsage(completion_tokens=638, prompt_tokens=10443, total_tokens=11081, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=638), prompt_tokens_details=PromptTokensDetails(audio_tokens=9476, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\2RaNq8rmsGA_8_0\part1_feedback.txt
#
# Evaluating Part 2...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/2RaNq8rmsGA_8_0/2RaNq8rmsGA_8_0_part_2.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 - The candidate speaks at length with a generally coherent structure, demonstrating a good command of vocabulary and grammar, though with some hesitation and minor errors that prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at length with a generally coherent structure, using discourse markers like "so" and "and" to link ideas. However, there are noticeable hesitations and fillers ("um," "like") that interrupt the flow, particularly when explaining her role as a translating manager. While she maintains topic relevance and provides a clear personal example, the pauses and repetition ("those group work and I always try to...") suggest a need for more spontaneous fluency to achieve a Band 8.
#
#    **Lexical Resource**: The candidate demonstrates a good range of topic-specific vocabulary, using terms like "translating manager," "shooting," "teamwork," and "client" appropriately. She also attempts to paraphrase ("perform their best" instead of "do well") and uses some less common phrases ("make chit-chat"). Her vocabulary is precise and relevant, allowing her to express her ideas clearly, which supports a Band 7.5 score.
#
#    **Grammatical Range and Accuracy**: The candidate uses a mix of simple and complex sentences, such as "I always try to assist models so that they can perform their best." However, there are frequent grammatical errors, including subject-verb agreement ("those should make teamwork"), incorrect prepositions ("give them water"), and awkward phrasing ("I can deliver it to the models"). While these errors do not impede understanding, they prevent a higher score in this criterion.
#
#    **Pronunciation**: The candidate's pronunciation is clear and easy to understand, with good use of intonation and rhythm that enhances her message. Her stress patterns are generally accurate, and she uses connected speech effectively. There are no significant pronunciation issues that hinder communication, which is consistent with a Band 7 score.
#
# Usage Info: CompletionUsage(completion_tokens=471, prompt_tokens=3968, total_tokens=4439, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=471), prompt_tokens_details=PromptTokensDetails(audio_tokens=3001, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\2RaNq8rmsGA_8_0\part2_feedback.txt
#
# Evaluating Part 3...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/2RaNq8rmsGA_8_0/2RaNq8rmsGA_8_0_part_3.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate speaks at length with generally smooth fluency, uses a good range of vocabulary and grammatical structures, and is easily understood throughout, though with some hesitation and minor grammatical errors that prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate demonstrates a good ability to speak at length on a range of topics, maintaining a generally smooth flow with only occasional pauses for thought. For example, when discussing jobs that require teamwork, she uses cohesive devices like "because" and "so" to link ideas logically. However, there are moments of hesitation, such as when she asks the examiner to repeat the question, which slightly disrupts the natural rhythm. Her responses are relevant and well-structured, showing flexibility in organizing ideas, which aligns with Band 7 features.
#
#    **Lexical Resource**: The candidate uses a wide and appropriate range of vocabulary, including less common terms like "preparations," "audiences," and "communicate," which demonstrates a strong command of lexical items. She effectively paraphrases ideas, such as using "work as a team" instead of repeating "teamwork." Her vocabulary is precise and varied across topics, from jobs to parenting to social skills, which is characteristic of a Band 7.5 candidate.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex structures, such as "I always have to ask what they want from me," which shows some grammatical variety. However, there are noticeable errors, like "I always have to ask what they want from me" (correct) but also "I think all those um all those like process of communications and those stuffs" where "process of communications" is awkward and "those stuffs" is grammatically incorrect. These errors, while not impeding understanding, prevent a higher score in this criterion.
#
#    **Pronunciation**: The candidate's pronunciation is clear and consistent throughout, with good use of intonation and stress that enhances meaning. For example, her stress on "teamwork" and "happy" helps emphasize key ideas. Her rhythm is natural, and she uses connected speech effectively, such as in "I work with buyers and also I perform in front of the audiences." There are no persistent mispronunciations that hinder understanding, which is typical of a Band 7 candidate.
#
# **Suggestions for Improvement**:
# To reach Band 8, the candidate should focus on reducing hesitation by preparing more concise responses and minimizing fillers like "um." Practicing complex sentence structures with varied conjunctions (e.g., "not only... but also") will improve grammatical range. Additionally, reviewing plural forms and prepositional phrases (e.g., "process of communication" instead of "process of communications") will enhance grammatical accuracy.
#
# Usage Info: CompletionUsage(completion_tokens=639, prompt_tokens=6643, total_tokens=7282, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=639), prompt_tokens_details=PromptTokensDetails(audio_tokens=5676, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\2RaNq8rmsGA_8_0\part3_feedback.txt
#
# Successfully evaluated: part1, part2, part3
# Saved: testset\2RaNq8rmsGA_8_0\model_feedback.txt
# Saved: testset\model_feedback\2RaNq8rmsGA_8_0.txt
#
# ==================================================
# Processing: 3C-uVgVCOIA_8_0
# ==================================================
#
# Evaluating Part 1...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/3C-uVgVCOIA_8_0/3C-uVgVCOIA_8_0_part_1.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 - The candidate speaks at length with generally smooth fluency and a good range of vocabulary, though some hesitation and grammatical errors prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate demonstrates a generally fluent speaking style with a good pace and natural rhythm. They are able to maintain the topic and provide extended answers, such as when explaining their job preferences and hometown. However, there are noticeable pauses and hesitations, particularly when searching for words ("um," "uh"), which slightly disrupt the flow. The use of cohesive devices is functional but limited, with a reliance on basic connectors like "and" and "so," which prevents a higher score.
#
#    **Lexical Resource**: The candidate displays a good range of vocabulary relevant to the topics discussed. They use specific terms like "Italian dish," "pasta," "bath town," and "commute," showing an ability to paraphrase and use topic-specific language effectively. Their vocabulary is generally precise and appropriate, contributing to clear communication. To reach Band 8, the candidate could incorporate more idiomatic expressions and less common collocations to demonstrate greater lexical flexibility.
#
#    **Grammatical Range and Accuracy**: The candidate uses a mix of simple and complex sentence structures, such as "I always went to Seoul to have fun with my friends," which shows an attempt at varied grammar. However, there are frequent grammatical errors, including subject-verb agreement issues ("I always went to Seoul to have fun with with my friends"), incorrect prepositions ("the reaction between them"), and tense inconsistencies ("I always went to Seoul to have fun with with my friends"). While these errors do not impede understanding, they prevent a higher score.
#
#    **Pronunciation**: The candidate's pronunciation is clear and easy to understand, with good use of intonation and stress patterns that contribute to natural-sounding speech. They articulate words accurately and maintain a consistent rhythm throughout their responses. The pronunciation of specific terms like "Annyeong" and "pasta" is correct, and there are no significant issues with connected speech. To improve, the candidate could focus on mastering more complex phonological features, such as linking and reduction, to achieve a more native-like rhythm.
#
# Usage Info: CompletionUsage(completion_tokens=523, prompt_tokens=6843, total_tokens=7366, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=523), prompt_tokens_details=PromptTokensDetails(audio_tokens=5876, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\3C-uVgVCOIA_8_0\part1_feedback.txt
#
# Evaluating Part 2...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/3C-uVgVCOIA_8_0/3C-uVgVCOIA_8_0_part_2.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 - The candidate speaks at length with generally good fluency and coherence, using a range of vocabulary and grammatical structures effectively, though with some hesitation and minor errors that prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate demonstrates a good ability to speak at length on the given topics, maintaining a generally smooth flow of ideas. For example, when discussing confusing text messages, the candidate provides a detailed personal anecdote about receiving a fake message claiming their father was taken, which shows effective topic development. However, there are noticeable hesitations, such as "um" and "uh" fillers, and a slight repetition when first asking for clarification ("Pardon?"). While the candidate uses some cohesive devices like "for example" and "so," the overall coherence is occasionally disrupted by these pauses, which is characteristic of a Band 7 speaker who can maintain topic development but with some effort.
#
#    **Lexical Resource**: The candidate displays a strong and flexible vocabulary, using precise and appropriate terms. Notable examples include "absurd," "deceive," and "emotional reaction," which demonstrate a good command of less common vocabulary. The candidate also uses idiomatic language effectively, such as "basically a lie," to convey meaning clearly. The vocabulary is varied and well-suited to the topics discussed, allowing for clear expression of ideas, which is a key feature of a Band 7.5 speaker.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex grammatical structures, such as the conditional "if they try to deceive people" and the relative clause "the text message with other people you cannot share the emotional reaction." However, there are frequent grammatical errors that affect accuracy. For instance, the candidate says, "the the for example" and "the the weird messages I got," which shows a lack of control over basic sentence structure. Additionally, there are issues with articles ("the the") and word order ("there are there's so many bad people out there"). These errors, while not impeding overall understanding, prevent the candidate from achieving a higher score.
#
#    **Pronunciation**: The candidate's pronunciation is clear and easy to understand, with good use of intonation and rhythm that contributes to the natural flow of speech. The candidate's stress and rhythm are generally accurate, making their speech sound fluent and expressive. For example, the phrase "my father was taken" is delivered with appropriate stress and intonation. There are no significant pronunciation issues that hinder comprehension, which is a hallmark of a Band 7 speaker.
#
# Usage Info: CompletionUsage(completion_tokens=598, prompt_tokens=4593, total_tokens=5191, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=598), prompt_tokens_details=PromptTokensDetails(audio_tokens=3626, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\3C-uVgVCOIA_8_0\part2_feedback.txt
#
# Evaluating Part 3...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/3C-uVgVCOIA_8_0/3C-uVgVCOIA_8_0_part_3.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 - The candidate speaks at length with generally good fluency and coherence, demonstrating a good range of vocabulary and grammatical structures. While there are some hesitation and grammatical errors, they do not significantly impede communication.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at length with a generally smooth flow, managing to stay on topic throughout the response. They use a range of cohesive devices like "basically," "and," and "so" to link ideas, which helps maintain coherence. However, there are noticeable hesitations and self-corrections, such as "um" and "the the," which interrupt the natural rhythm and prevent a higher score. The topic development is logical but could be more sophisticated with better sequencing of ideas.
#
#    **Lexical Resource**: The candidate demonstrates a good range of vocabulary, using specific terms like "nerve disability," "car accident," and "brain chip" to describe their chosen job. They also use less common phrases like "it would be done" and "doing hard work," showing an attempt at varied expression. The vocabulary is generally precise and appropriate for the topic, allowing for clear communication of complex ideas.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex sentences, such as "the brain and the body cannot be fully connected because of the accident, physically." However, there are frequent grammatical errors, including subject-verb agreement issues ("the people are doing hard work for doing that"), incorrect prepositions ("in the company is that in the field"), and awkward phrasing ("the the"). While these errors don't significantly hinder understanding, they prevent a higher score.
#
#    **Pronunciation**: The candidate's pronunciation is generally clear and easy to understand. They use appropriate stress and intonation to convey meaning, such as emphasizing "Neuralink" and "brain chip." There are no persistent mispronunciations that cause confusion. However, some words are slightly unclear, like "nerve" and "car accident," and the rhythm can be uneven due to hesitations, which slightly affects overall fluency.
#
# Usage Info: CompletionUsage(completion_tokens=499, prompt_tokens=6043, total_tokens=6542, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=499), prompt_tokens_details=PromptTokensDetails(audio_tokens=5076, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\3C-uVgVCOIA_8_0\part3_feedback.txt
#
# Successfully evaluated: part1, part2, part3
# Saved: testset\3C-uVgVCOIA_8_0\model_feedback.txt
# Saved: testset\model_feedback\3C-uVgVCOIA_8_0.txt
#
# ==================================================
# Processing: 5OzX7yMTsmw_8_0
# ==================================================
#
# Evaluating Part 1...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/5OzX7yMTsmw_8_0/5OzX7yMTsmw_8_0_part_1.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate speaks at length with generally good fluency and coherence, using a range of vocabulary and grammatical structures, though with some hesitation and occasional errors that prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate generally speaks at length without significant pauses, demonstrating a good ability to maintain topic development. For example, when discussing his hometown, he provides a coherent narrative about his childhood, mentioning family members and the peaceful environment. He uses cohesive devices like "although," "however," and "so" effectively to link ideas. However, there are moments of hesitation, such as when he says, "like a... I just... I just determined to like a view like my life as some sort of a challenge," which indicates a slight struggle to formulate complex thoughts on the spot. This is typical of Band 7, where fluency is generally smooth but not effortless.
#
#    **Lexical Resource**: The candidate demonstrates a good range of vocabulary, including less common terms like "self-improvement," "discipline," and "urban/suburban." He also uses idiomatic expressions such as "a significant moment" and "a milestone," which shows flexibility in word choice. His vocabulary is precise and relevant to the topics discussed, such as "side hustles" and "financial stability." However, there are minor issues with word choice, such as saying "like a... I just determined to like a view like my life as some sort of a challenge," where the repetition of "like" and the awkward phrasing slightly reduce clarity. This level of lexical resource is characteristic of Band 7.5.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex sentences, such as when he says, "I just determined to like a view like my life as some sort of a challenge instead of the uh like some sort of a impasse I supposed to face." While he shows an awareness of complex structures, there are frequent grammatical errors, including subject-verb agreement issues ("I just determined to like a view like my life as some sort of a challenge"), incorrect prepositions ("like a... I just determined to like a view like my life"), and awkward phrasing ("I'm just like a still struggling with it"). These errors, while not impeding understanding, prevent a higher score. The candidate's ability to use a range of structures is evident, but accuracy is inconsistent, placing him in the Band 6.5 range.
#
#    **Pronunciation**: The candidate's pronunciation is generally clear and easy to understand, with a noticeable but not distracting accent. His intonation and rhythm are mostly natural, contributing to the overall fluency. For example, his delivery of "I just determined to like a view like my life as some sort of a challenge" is understandable despite the grammatical issues. However, there are some mispronunciations, such as "like a... I just determined to like a view like my life as some sort of a challenge," where the repetition of "like" and the awkward phrasing affect clarity. The candidate's pronunciation is effective for communication, aligning with Band 7.
#
# Usage Info: CompletionUsage(completion_tokens=715, prompt_tokens=13668, total_tokens=14383, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=715), prompt_tokens_details=PromptTokensDetails(audio_tokens=12701, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\5OzX7yMTsmw_8_0\part1_feedback.txt
#
# Evaluating Part 2...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/5OzX7yMTsmw_8_0/5OzX7yMTsmw_8_0_part_2.mp3
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate delivers a coherent and relevant response with a good range of vocabulary and grammatical structures, though some hesitation and grammatical inaccuracies prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at length with a generally smooth flow, maintaining topic relevance throughout the response. They use cohesive devices such as "so," "and," and "first of all" to structure their ideas logically. However, there are noticeable hesitations and self-corrections (e.g., "uh, expensive activity, so actually, that's uh...") which slightly disrupt the natural rhythm. While the candidate manages to develop their points coherently, the pauses and repetition prevent a higher score in this criterion.
#
#    **Lexical Resource**: The candidate demonstrates a good range of vocabulary, using topic-specific terms like "gym session," "muscle mass," "supplements," and "food consummation" effectively. They also attempt to paraphrase with phrases like "it doesn't matter whether I'm a man or a woman" and "it actually takes the discipline first of all." The vocabulary is generally precise and appropriate for the topic, showing flexibility and awareness of style, which supports a strong Lexical Resource score.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex structures, such as "it actually takes a lot of supplements and even a discipline and even a food consummation," though some of these are grammatically awkward. There are frequent errors in verb forms ("it actually requires the protein powder and just like a bunch of like supplements") and article usage ("a proper amount of food calories"). While the candidate shows an effort to use varied grammar, the frequency of errors affects clarity and prevents a higher score.
#
# ...
#
# Response:
#
# 1. **Overall Band Score**: 7.0 – The candidate demonstrates a good command of English with clear fluency and coherence, using a range of vocabulary and grammatical structures effectively, though with some noticeable errors and hesitation that prevent a higher score.
#
# 2. **Individual Band Scores**:
#    - Fluency and Coherence: 7.0
#    - Lexical Resource: 7.5
#    - Grammatical Range and Accuracy: 6.5
#    - Pronunciation: 7.0
#
# 3. **Feedback Paragraphs**:
#
#    **Fluency and Coherence**: The candidate speaks at length with a generally smooth flow, using discourse markers like "so," "like," and "but" to connect ideas. For example, they use "so, I think that's the reason" to transition between points effectively. However, there are noticeable hesitations and repetitions, such as "like a" and "like a" at the start of multiple sentences, which slightly disrupt the natural rhythm. Despite these minor issues, the candidate maintains coherence throughout the responses, making their ideas easy to follow.
#
#    **Lexical Resource**: The candidate demonstrates a good range of vocabulary, using terms like "discipline," "generational wealth," "tangible," and "procrastinate" appropriately. They also show flexibility by paraphrasing ideas, such as explaining that "the rich doesn't come from lucky" instead of "the rich don't come from luck." This variety and precision in word choice support a Band 7.5 score, as the vocabulary is used flexibly and accurately across different topics.
#
#    **Grammatical Range and Accuracy**: The candidate attempts a mix of simple and complex structures, such as "they are no longer dependent on the location or even the time," which shows good grammatical awareness. However, there are frequent grammatical errors, including subject-verb agreement issues ("the rich doesn't come from lucky"), incorrect prepositions ("give themselves in the temptation"), and awkward phrasing ("the way they can just like a screw things up"). These errors, while not impeding understanding, prevent a higher score in this criterion.
#
#    **Pronunciation**: The candidate's pronunciation is clear and consistent, with good use of intonation and stress patterns that enhance meaning. For example, their emphasis on "poor" and "rich" effectively contrasts the two ideas. The rhythm of their speech is natural, and there are no significant mispronunciations that hinder comprehension. This consistent and intelligible delivery supports a Band 7 score, as the candidate communicates effectively despite occasional grammatical inaccuracies.
#
# Usage Info: CompletionUsage(completion_tokens=534, prompt_tokens=10094, total_tokens=10628, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=None, reasoning_tokens=None, rejected_prediction_tokens=None, text_tokens=534), prompt_tokens_details=PromptTokensDetails(audio_tokens=9127, cached_tokens=None, text_tokens=967))
#
# Evaluation Complete.
#
# Saved: testset\5OzX7yMTsmw_8_0\part3_feedback.txt
#
# Successfully evaluated: part1, part2, part3
# Saved: testset\5OzX7yMTsmw_8_0\model_feedback.txt
# Saved: testset\model_feedback\5OzX7yMTsmw_8_0.txt
#
# ==================================================
# Processing: 5ycaCwb6xvg_5_5
# ==================================================
#
# Evaluating Part 1...
# Evaluating audio: https://github.com/hk414/automatic-feedback-for-ielts-speaking-asr/raw/refs/heads/main/testset/5ycaCwb6xvg_5_5/5ycaCwb6xvg_5_5_part_1.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 39
#      37 print("\nEvaluating Part 1...")
#      38 try:
# ---> 39     p1_result = evaluator.evaluate_audio(part_one)
#      40     results['part1'] = p1_result
#      41     save_txt(p1_result, str(subdir / "part1_feedback.txt"))
#
# File c:\Users\User\Downloads\h-fyp\project\QwenIELTSEvaluator.py:88, in QwenIELTSEvaluator.evaluate_audio(self, audio_url, model)
#      85 messages = self._build_messages(audio_url)
#      87 try:
# ---> 88     completion = self.client.chat.completions.create(
#      89         model=model,
#      90         messages=messages,
#      91         modalities=["text"],
#      92         stream=True,
#      93         stream_options={"include_usage": True},
#      94     )
#      96     response_text = ""
#      97     usage_info = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)
#    1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     980 response = None
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#     988     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_sync\http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File c:\Users\User\.conda\envs\venv\Lib\ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File c:\Users\User\.conda\envs\venv\Lib\ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
